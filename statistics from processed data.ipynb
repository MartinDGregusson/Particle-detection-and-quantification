# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from multiple_histograms import multiple_histograms, extract_dicts_from_pickled_objects, extract_dicts_from_pickled_dicts

# %%
num_bins = 25
bins_range = (0,80)
file_names = ["pickled_datasets/Har_20h_600_stats.pkl",
              "pickled_datasets/Har_20h_700_stats.pkl",
              "pickled_datasets/Har_20h_800_stats.pkl",
              "pickled_datasets/Har_20h_900_stats.pkl"]

# %%
#If you saved processes using process.save_current
#dict_list, names = extract_dicts_from_pickled_objects(file_names, bins_range, num_bins)

#If you saved statistics using process.save_stats_dict
dict_list, names = extract_dicts_from_pickled_dicts(file_names)

#If the processes are already loaded into the notebook
#dict_list, names = extract_dicts_from_objects(processes, bins_range, num_bins)

# %%
names = ["600 °C", "700 °C", "800 °C", "900 °C"]

# %%
fig1, ax1, fig2, ax2 = multiple_histograms(bins_range, num_bins, dict_list, names)
plt.show()
